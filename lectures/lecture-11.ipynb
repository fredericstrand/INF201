# %% [markdown]
# # Lecture 11: Assertions and Exeptions

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 32
#      30 cells = []
#      31 for idx, (pt1, pt2) in enumerate(zip(point_values[:-1], point_values[1:])):
# ---> 32     cells.append(Line[idx, [pt1, pt2]])
#      34 cells.append(BoundaryPoint(len(cells), point_values[0]))
#      35 cells.append(BoundaryPoint(len(cells), point_values[-1]))
#
# TypeError: type 'Line' is not subscriptable

# %%
import numpy as np
from abc import ABC, abstractmethod

class Point:
    def __init__(self, value, index) -> None:
        self._value = value
        self._index = index
        
class Cell():
    def __init__(self, id, points):
        self._id = id
        self._points = points

    @abstractmethod
    def cell_size(self):
        pass

    @property
    def id(self):
        return self._id

class Line(Cell):
    def __init__(self, id, points):
        super().__init__(id, points)

    def cell_size(self):
        return self._points[1] - self._points[0]

class BoundaryPoint(Cell):
    def __init__(self, id, points):
        super().__init__(id, points)

    def cell_size(self):
        return 0.0

if __name__ == "__main__":
    point_values = np.linspace(0, 1, 100)
    points = []
    for idx, pt in enumerate(point_values):
        points.append(Point(pt, idx))

    cells = []
    for idx, (pt1, pt2) in enumerate(zip(point_values[:-1], point_values[1:])):
        cells.append(Line(idx, [pt1, pt2]))
        cells.append(BoundaryPoint(len(cells), point_values[0]))
        cells.append(BoundaryPoint(len(cells), point_values[-1]))

    for c in cells:
        print(f"Cell {c.id}: size is {c.cell_size()}")
# Out:
# Cell 0: size is 0.010101010101010102
# Cell 1: size is 0.0
# Cell 2: size is 0.0
# Cell 1: size is 0.010101010101010102
# Cell 4: size is 0.0
# Cell 5: size is 0.0
# Cell 2: size is 0.0101010101010101
# Cell 7: size is 0.0
# Cell 8: size is 0.0
# Cell 3: size is 0.010101010101010104
# Cell 10: size is 0.0
# Cell 11: size is 0.0
# Cell 4: size is 0.010101010101010104
# Cell 13: size is 0.0
# Cell 14: size is 0.0
# Cell 5: size is 0.010101010101010097
# Cell 16: size is 0.0
# Cell 17: size is 0.0
# Cell 6: size is 0.01010101010101011
# Cell 19: size is 0.0
# Cell 20: size is 0.0
# Cell 7: size is 0.010101010101010097
# Cell 22: size is 0.0
# Cell 23: size is 0.0
# Cell 8: size is 0.010101010101010097
# Cell 25: size is 0.0
# Cell 26: size is 0.0
# Cell 9: size is 0.01010101010101011
# Cell 28: size is 0.0
# Cell 29: size is 0.0
# Cell 10: size is 0.010101010101010097
# Cell 31: size is 0.0
# Cell 32: size is 0.0
# Cell 11: size is 0.010101010101010097
# Cell 34: size is 0.0
# Cell 35: size is 0.0
# Cell 12: size is 0.01010101010101011
# Cell 37: size is 0.0
# Cell 38: size is 0.0
# Cell 13: size is 0.01010101010101011
# Cell 40: size is 0.0
# Cell 41: size is 0.0
# Cell 14: size is 0.010101010101010083
# Cell 43: size is 0.0
# Cell 44: size is 0.0
# Cell 15: size is 0.01010101010101011
# Cell 46: size is 0.0
# Cell 47: size is 0.0
# Cell 16: size is 0.01010101010101011
# Cell 49: size is 0.0
# Cell 50: size is 0.0
# Cell 17: size is 0.010101010101010083
# Cell 52: size is 0.0
# Cell 53: size is 0.0
# Cell 18: size is 0.01010101010101011
# Cell 55: size is 0.0
# Cell 56: size is 0.0
# Cell 19: size is 0.01010101010101011
# Cell 58: size is 0.0
# Cell 59: size is 0.0
# Cell 20: size is 0.010101010101010083
# Cell 61: size is 0.0
# Cell 62: size is 0.0
# Cell 21: size is 0.01010101010101011
# Cell 64: size is 0.0
# Cell 65: size is 0.0
# Cell 22: size is 0.01010101010101011
# Cell 67: size is 0.0
# Cell 68: size is 0.0
# Cell 23: size is 0.010101010101010083
# Cell 70: size is 0.0
# Cell 71: size is 0.0
# Cell 24: size is 0.01010101010101011
# Cell 73: size is 0.0
# Cell 74: size is 0.0
# Cell 25: size is 0.01010101010101011
# Cell 76: size is 0.0
# Cell 77: size is 0.0
# Cell 26: size is 0.01010101010101011
# Cell 79: size is 0.0
# Cell 80: size is 0.0
# Cell 27: size is 0.01010101010101011
# Cell 82: size is 0.0
# Cell 83: size is 0.0
# Cell 28: size is 0.010101010101010055
# Cell 85: size is 0.0
# Cell 86: size is 0.0
# Cell 29: size is 0.01010101010101011
# Cell 88: size is 0.0
# Cell 89: size is 0.0
# Cell 30: size is 0.01010101010101011
# Cell 91: size is 0.0
# Cell 92: size is 0.0
# Cell 31: size is 0.01010101010101011
# Cell 94: size is 0.0
# Cell 95: size is 0.0
# Cell 32: size is 0.01010101010101011
# Cell 97: size is 0.0
# Cell 98: size is 0.0
# Cell 33: size is 0.01010101010101011
# Cell 100: size is 0.0
# Cell 101: size is 0.0
# Cell 34: size is 0.01010101010101011
# Cell 103: size is 0.0
# Cell 104: size is 0.0
# Cell 35: size is 0.010101010101010055
# Cell 106: size is 0.0
# Cell 107: size is 0.0
# Cell 36: size is 0.01010101010101011
# Cell 109: size is 0.0
# Cell 110: size is 0.0
# Cell 37: size is 0.01010101010101011
# Cell 112: size is 0.0
# Cell 113: size is 0.0
# Cell 38: size is 0.01010101010101011
# Cell 115: size is 0.0
# Cell 116: size is 0.0
# Cell 39: size is 0.01010101010101011
# Cell 118: size is 0.0
# Cell 119: size is 0.0
# Cell 40: size is 0.01010101010101011
# Cell 121: size is 0.0
# Cell 122: size is 0.0
# Cell 41: size is 0.010101010101010055
# Cell 124: size is 0.0
# Cell 125: size is 0.0
# Cell 42: size is 0.01010101010101011
# Cell 127: size is 0.0
# Cell 128: size is 0.0
# Cell 43: size is 0.01010101010101011
# Cell 130: size is 0.0
# Cell 131: size is 0.0
# Cell 44: size is 0.01010101010101011
# Cell 133: size is 0.0
# Cell 134: size is 0.0
# Cell 45: size is 0.01010101010101011
# Cell 136: size is 0.0
# Cell 137: size is 0.0
# Cell 46: size is 0.01010101010101011
# Cell 139: size is 0.0
# Cell 140: size is 0.0
# Cell 47: size is 0.010101010101010055
# Cell 142: size is 0.0
# Cell 143: size is 0.0
# Cell 48: size is 0.01010101010101011
# Cell 145: size is 0.0
# Cell 146: size is 0.0
# Cell 49: size is 0.01010101010101011
# Cell 148: size is 0.0
# Cell 149: size is 0.0
# Cell 50: size is 0.010101010101010166
# Cell 151: size is 0.0
# Cell 152: size is 0.0
# Cell 51: size is 0.010101010101010055
# Cell 154: size is 0.0
# Cell 155: size is 0.0
# Cell 52: size is 0.010101010101010055
# Cell 157: size is 0.0
# Cell 158: size is 0.0
# Cell 53: size is 0.010101010101010166
# Cell 160: size is 0.0
# Cell 161: size is 0.0
# Cell 54: size is 0.010101010101010055
# Cell 163: size is 0.0
# Cell 164: size is 0.0
# Cell 55: size is 0.010101010101010166
# Cell 166: size is 0.0
# Cell 167: size is 0.0
# Cell 56: size is 0.010101010101010055
# Cell 169: size is 0.0
# Cell 170: size is 0.0
# Cell 57: size is 0.010101010101010055
# Cell 172: size is 0.0
# Cell 173: size is 0.0
# Cell 58: size is 0.010101010101010166
# Cell 175: size is 0.0
# Cell 176: size is 0.0
# Cell 59: size is 0.010101010101010055
# Cell 178: size is 0.0
# Cell 179: size is 0.0
# Cell 60: size is 0.010101010101010166
# Cell 181: size is 0.0
# Cell 182: size is 0.0
# Cell 61: size is 0.010101010101010055
# Cell 184: size is 0.0
# Cell 185: size is 0.0
# Cell 62: size is 0.010101010101010166
# Cell 187: size is 0.0
# Cell 188: size is 0.0
# Cell 63: size is 0.010101010101010055
# Cell 190: size is 0.0
# Cell 191: size is 0.0
# Cell 64: size is 0.010101010101010055
# Cell 193: size is 0.0
# Cell 194: size is 0.0
# Cell 65: size is 0.010101010101010166
# Cell 196: size is 0.0
# Cell 197: size is 0.0
# Cell 66: size is 0.010101010101010055
# Cell 199: size is 0.0
# Cell 200: size is 0.0
# Cell 67: size is 0.010101010101010166
# Cell 202: size is 0.0
# Cell 203: size is 0.0
# Cell 68: size is 0.010101010101010055
# Cell 205: size is 0.0
# Cell 206: size is 0.0
# Cell 69: size is 0.010101010101010166
# Cell 208: size is 0.0
# Cell 209: size is 0.0
# Cell 70: size is 0.010101010101010055
# Cell 211: size is 0.0
# Cell 212: size is 0.0
# Cell 71: size is 0.010101010101010055
# Cell 214: size is 0.0
# Cell 215: size is 0.0
# Cell 72: size is 0.010101010101010166
# Cell 217: size is 0.0
# Cell 218: size is 0.0
# Cell 73: size is 0.010101010101010055
# Cell 220: size is 0.0
# Cell 221: size is 0.0
# Cell 74: size is 0.010101010101010166
# Cell 223: size is 0.0
# Cell 224: size is 0.0
# Cell 75: size is 0.010101010101010055
# Cell 226: size is 0.0
# Cell 227: size is 0.0
# Cell 76: size is 0.010101010101010055
# Cell 229: size is 0.0
# Cell 230: size is 0.0
# Cell 77: size is 0.010101010101010166
# Cell 232: size is 0.0
# Cell 233: size is 0.0
# Cell 78: size is 0.010101010101010055
# Cell 235: size is 0.0
# Cell 236: size is 0.0
# Cell 79: size is 0.010101010101010166
# Cell 238: size is 0.0
# Cell 239: size is 0.0
# Cell 80: size is 0.010101010101010055
# Cell 241: size is 0.0
# Cell 242: size is 0.0
# Cell 81: size is 0.010101010101010166
# Cell 244: size is 0.0
# Cell 245: size is 0.0
# Cell 82: size is 0.010101010101010055
# Cell 247: size is 0.0
# Cell 248: size is 0.0
# Cell 83: size is 0.010101010101010055
# Cell 250: size is 0.0
# Cell 251: size is 0.0
# Cell 84: size is 0.010101010101010166
# Cell 253: size is 0.0
# Cell 254: size is 0.0
# Cell 85: size is 0.010101010101010055
# Cell 256: size is 0.0
# Cell 257: size is 0.0
# Cell 86: size is 0.010101010101010166
# Cell 259: size is 0.0
# Cell 260: size is 0.0
# Cell 87: size is 0.010101010101010055
# Cell 262: size is 0.0
# Cell 263: size is 0.0
# Cell 88: size is 0.010101010101010166
# Cell 265: size is 0.0
# Cell 266: size is 0.0
# Cell 89: size is 0.010101010101010055
# Cell 268: size is 0.0
# Cell 269: size is 0.0
# Cell 90: size is 0.010101010101010055
# Cell 271: size is 0.0
# Cell 272: size is 0.0
# Cell 91: size is 0.010101010101010166
# Cell 274: size is 0.0
# Cell 275: size is 0.0
# Cell 92: size is 0.010101010101010055
# Cell 277: size is 0.0
# Cell 278: size is 0.0
# Cell 93: size is 0.010101010101010166
# Cell 280: size is 0.0
# Cell 281: size is 0.0
# Cell 94: size is 0.010101010101010055
# Cell 283: size is 0.0
# Cell 284: size is 0.0
# Cell 95: size is 0.010101010101010055
# Cell 286: size is 0.0
# Cell 287: size is 0.0
# Cell 96: size is 0.010101010101010166
# Cell 289: size is 0.0
# Cell 290: size is 0.0
# Cell 97: size is 0.010101010101010055
# Cell 292: size is 0.0
# Cell 293: size is 0.0
# Cell 98: size is 0.010101010101010055
# Cell 295: size is 0.0
# Cell 296: size is 0.0
